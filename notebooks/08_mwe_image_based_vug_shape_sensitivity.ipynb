# %% [markdown]
# # MWE 08 - Image-based vug sensitivity with multi-realization baselines
#
# This notebook quantifies how synthetic **spherical** and **ellipsoidal** vugs
# perturb porosity and absolute permeability (`Kabs`) in a connected porous matrix.
#
# Updated study design (requested):
#
# - **15 baseline realizations** (no vugs), generated independently.
# - At least **5 spherical vug configurations**.
# - At least **5 ellipsoidal configurations stretched in the flow direction**.
# - At least **5 ellipsoidal configurations stretched orthogonal to flow**.
# - **Plotly pore-network visualization for every solved case**.
#
# Important correction relative to the previous notebook revision:
#
# - The earlier ellipsoids were effectively stretched orthogonal to flow.
# - This notebook now includes both orientation families explicitly.
#
# Assumptions to keep in mind:
#
# - Voxel size is fixed at `10 um` (synthetic digital rock resolution).
# - One centered vug per realization is used to isolate shape/size effects.
# - Permeability is evaluated along one axis (`x`).
# - Synthetic grayscale contrast/noise is simplified and may not match real CT artifacts.

# %%
from __future__ import annotations

import os
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import porespy as ps
from scipy import ndimage as ndi

try:
    from tqdm.auto import tqdm as _tqdm
except Exception:  # pragma: no cover - optional dependency in notebook runtime
    _tqdm = None

from voids.geom import characteristic_size
from voids.graph.metrics import coordination_numbers
from voids.physics.petrophysics import absolute_porosity, effective_porosity
from voids.physics.singlephase import (
    FluidSinglePhase,
    PressureBC,
    SinglePhaseOptions,
    solve,
)
from voids.visualization import plot_network_plotly
from voids.workflows import binarize_grayscale_volume, extract_spanning_porespy_network


def iter_progress(
    iterable,
    *,
    desc: str | None = None,
    total: int | None = None,
    enabled: bool = True,
    leave: bool = False,
):
    """Wrap iterables with tqdm when requested and available."""

    if not enabled or _tqdm is None:
        return iterable
    return _tqdm(
        iterable,
        desc=desc,
        total=total,
        dynamic_ncols=True,
        leave=leave,
    )

# %%
# Study controls
VOXEL_SIZE_M = 10.0e-6  # 10 um
SHAPE = (60, 60, 60)
FLOW_AXIS = "x"
FLOW_AXIS_INDEX = {"x": 0, "y": 1, "z": 2}[FLOW_AXIS]

N_BASELINES = 30
TARGET_MATRIX_POROSITY = 0.15
BLOBINESS = 1.8
BASE_SEED = 20260305
MAX_MATRIX_TRIES = 120

# >= 5 spherical configurations
SPHERE_RADII_VOX = [4, 6, 8, 10, 12]

# >= 5 ellipsoids stretched in flow direction (x)
ELLIPSOID_FLOW_RADII_VOX = [
    (9, 5, 5),
    (11, 6, 6),
    (13, 7, 7),
    (15, 8, 8),
    (17, 9, 9),
]

# >= 5 ellipsoids stretched orthogonal to flow (z)
ELLIPSOID_ORTH_RADII_VOX = [
    (5, 5, 9),
    (6, 6, 11),
    (7, 7, 13),
    (8, 8, 15),
    (9, 9, 17),
]

GRAYSCALE_VOID_MEAN = 65.0
GRAYSCALE_SOLID_MEAN = 185.0
GRAYSCALE_NOISE_STD = 8.0

PLOTLY_MAX_THROATS = 1500
PLOTLY_LAYOUT = {"width": 900, "height": 650}
# Disable screen-space size clipping to preserve full relative pore/throat size range.
PLOTLY_SIZE_LIMITS = (None, None)
USE_TQDM = os.environ.get("VOIDS_DISABLE_TQDM", "0") != "1"

# Optional fast mode for development smoke checks only
SMOKE_MODE = os.environ.get("VOIDS_VUG_SMOKE", "0") == "1"
if SMOKE_MODE:
    N_BASELINES = 1
    SPHERE_RADII_VOX = SPHERE_RADII_VOX[:1]
    ELLIPSOID_FLOW_RADII_VOX = ELLIPSOID_FLOW_RADII_VOX[:1]
    ELLIPSOID_ORTH_RADII_VOX = ELLIPSOID_ORTH_RADII_VOX[:1]

print("shape:", SHAPE, "| target matrix porosity:", TARGET_MATRIX_POROSITY)
print("voxel size:", VOXEL_SIZE_M, "m")
print("flow axis:", FLOW_AXIS)
print("n baselines:", N_BASELINES)
print("sphere configs:", len(SPHERE_RADII_VOX))
print("ellipsoid-flow configs:", len(ELLIPSOID_FLOW_RADII_VOX))
print("ellipsoid-orth configs:", len(ELLIPSOID_ORTH_RADII_VOX))
# Out:
# shape: (60, 60, 60) | target matrix porosity: 0.15
# voxel size: 1e-05 m
# flow axis: x
# n baselines: 30
# sphere configs: 5
# ellipsoid-flow configs: 5
# ellipsoid-orth configs: 5

# %%
def has_spanning_cluster(void_mask: np.ndarray, axis_index: int) -> bool:
    """Return True if at least one connected void cluster spans the chosen axis."""

    labels, n_labels = ndi.label(np.asarray(void_mask, dtype=bool))
    if n_labels == 0:
        return False
    inlet_labels = np.unique(np.take(labels, indices=0, axis=axis_index))
    outlet_labels = np.unique(np.take(labels, indices=-1, axis=axis_index))
    inlet_labels = inlet_labels[inlet_labels > 0]
    outlet_labels = outlet_labels[outlet_labels > 0]
    return np.intersect1d(inlet_labels, outlet_labels).size > 0


def generate_connected_matrix(
    *,
    shape: tuple[int, int, int],
    porosity: float,
    blobiness: float,
    axis_index: int,
    seed_start: int,
    max_tries: int,
    show_progress: bool = False,
    progress_desc: str | None = None,
) -> tuple[np.ndarray, int]:
    """Generate blobs matrix and retry seeds until it spans the selected axis."""

    seed_iterator = iter_progress(
        range(max_tries),
        desc=progress_desc or f"seed search @ {seed_start}",
        total=max_tries,
        enabled=show_progress,
        leave=False,
    )
    for i in seed_iterator:
        seed = seed_start + i
        matrix = np.asarray(
            ps.generators.blobs(
                shape=shape,
                porosity=porosity,
                blobiness=blobiness,
                seed=seed,
            ),
            dtype=bool,
        )
        if has_spanning_cluster(matrix, axis_index):
            return matrix, seed
    raise RuntimeError(
        f"Could not generate spanning matrix for seed_start={seed_start}"
    )


def insert_ellipsoidal_vug(
    matrix_void: np.ndarray,
    *,
    radii_vox: tuple[int, int, int],
    center: tuple[int, int, int] | None = None,
) -> tuple[np.ndarray, np.ndarray]:
    """Insert one axis-aligned ellipsoidal vug in a binary void image."""

    out = np.asarray(matrix_void, dtype=bool).copy()
    nx, ny, nz = out.shape
    cx, cy, cz = center if center is not None else (nx // 2, ny // 2, nz // 2)
    rx, ry, rz = (float(radii_vox[0]), float(radii_vox[1]), float(radii_vox[2]))
    if min(rx, ry, rz) <= 0:
        raise ValueError("All ellipsoid radii must be positive")

    x = np.arange(nx, dtype=float) - cx
    y = np.arange(ny, dtype=float) - cy
    z = np.arange(nz, dtype=float) - cz
    xx, yy, zz = np.meshgrid(x, y, z, indexing="ij")
    ellipsoid_mask = (xx / rx) ** 2 + (yy / ry) ** 2 + (zz / rz) ** 2 <= 1.0
    out[ellipsoid_mask] = True
    return out, ellipsoid_mask


def insert_spherical_vug(
    matrix_void: np.ndarray,
    *,
    radius_vox: int,
    center: tuple[int, int, int] | None = None,
) -> tuple[np.ndarray, np.ndarray]:
    """Insert one spherical vug (special case of ellipsoid)."""

    radius = int(radius_vox)
    return insert_ellipsoidal_vug(
        matrix_void,
        radii_vox=(radius, radius, radius),
        center=center,
    )


def equivalent_radius_vox(radii_vox: tuple[int, int, int]) -> float:
    """Equivalent sphere radius preserving ellipsoid volume."""

    rx, ry, rz = radii_vox
    return float((rx * ry * rz) ** (1.0 / 3.0))


def save_network_png_matplotlib(
    *,
    net,
    pore_pressure: np.ndarray,
    png_path: Path,
    title: str,
    max_throats: int = 1500,
) -> None:
    """Save a static 3D network PNG using Matplotlib as a fallback exporter."""

    coords = np.asarray(net.pore_coords, dtype=float)
    conns = np.asarray(net.throat_conns, dtype=int)

    if conns.shape[0] > max_throats:
        sample_idx = np.linspace(0, conns.shape[0] - 1, max_throats, dtype=int)
        conns_plot = conns[sample_idx]
    else:
        conns_plot = conns

    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection="3d")
    ax.set_title(title)

    for i, j in conns_plot:
        ax.plot(
            [coords[i, 0], coords[j, 0]],
            [coords[i, 1], coords[j, 1]],
            [coords[i, 2], coords[j, 2]],
            color="0.45",
            alpha=0.18,
            linewidth=0.4,
        )

    scatter = ax.scatter(
        coords[:, 0],
        coords[:, 1],
        coords[:, 2],
        c=np.asarray(pore_pressure, dtype=float),
        s=8,
        cmap="viridis",
        alpha=0.9,
    )
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    fig.colorbar(scatter, ax=ax, shrink=0.7, pad=0.08, label="Pressure [Pa]")
    fig.tight_layout()
    fig.savefig(png_path, dpi=220, bbox_inches="tight")
    plt.close(fig)


def make_synthetic_grayscale(binary_void: np.ndarray, seed: int) -> np.ndarray:
    """Build a synthetic grayscale image from binary void/solid phases."""

    rng = np.random.default_rng(seed)
    base = np.where(binary_void, GRAYSCALE_VOID_MEAN, GRAYSCALE_SOLID_MEAN)
    noise = rng.normal(loc=0.0, scale=GRAYSCALE_NOISE_STD, size=binary_void.shape)
    gray = np.clip(base + noise, 0.0, 255.0)
    return gray.astype(float)


def evaluate_case(
    *,
    baseline_id: int,
    case_name: str,
    family: str,
    orientation: str,
    config_index: int,
    radii_vox: tuple[int, int, int],
    binary_void: np.ndarray,
    baseline_void: np.ndarray,
    case_seed: int,
    baseline_kabs: float | None,
) -> tuple[dict[str, float | int | str], dict[str, object]]:
    """Run binarization -> extraction -> solve, then create Plotly network view."""

    added_void_vox = int(np.count_nonzero(binary_void & ~baseline_void))

    gray = make_synthetic_grayscale(binary_void, seed=case_seed)
    segmented, threshold = binarize_grayscale_volume(
        gray,
        method="otsu",
        void_phase="dark",
    )

    extract = extract_spanning_porespy_network(
        segmented.astype(int),
        voxel_size=VOXEL_SIZE_M,
        flow_axis=FLOW_AXIS,
        length_unit="m",
        provenance_notes={
            "study": "image_based_vug_sensitivity_multibaseline",
            "baseline_id": baseline_id,
            "case_name": case_name,
            "family": family,
            "orientation": orientation,
            "config_index": config_index,
            "radii_vox": list(radii_vox),
            "threshold_otsu": threshold,
            "case_seed": case_seed,
        },
    )
    net = extract.net

    bc = PressureBC(
        f"inlet_{FLOW_AXIS}min",
        f"outlet_{FLOW_AXIS}max",
        pin=2.0e5,
        pout=1.0e5,
    )
    res = solve(
        net,
        fluid=FluidSinglePhase(viscosity=1.0e-3),
        bc=bc,
        axis=FLOW_AXIS,
        options=SinglePhaseOptions(
            conductance_model="valvatne_blunt_baseline", solver="direct"
        ),
    )

    pore_size_m, pore_size_field = characteristic_size(
        net.pore, expected_shape=(net.Np,)
    )
    coordination = coordination_numbers(net)
    kabs = float(res.permeability[FLOW_AXIS])
    k_ratio = 1.0 if baseline_kabs is None else (kabs / baseline_kabs)

    fig = plot_network_plotly(
        net,
        point_scalars=res.pore_pressure,
        max_throats=PLOTLY_MAX_THROATS,
        point_size_limits=PLOTLY_SIZE_LIMITS,
        throat_size_limits=PLOTLY_SIZE_LIMITS,
        title=(
            f"B{baseline_id} | {case_name} | K{FLOW_AXIS}={kabs:.3e} m2 | "
            f"phi={float(segmented.mean()):.4f}"
        ),
        layout_kwargs=PLOTLY_LAYOUT,
    )

    row = {
        "baseline_id": baseline_id,
        "case": case_name,
        "family": family,
        "orientation": orientation,
        "config_index": config_index,
        "rx_vox": int(radii_vox[0]),
        "ry_vox": int(radii_vox[1]),
        "rz_vox": int(radii_vox[2]),
        "equivalent_radius_vox": equivalent_radius_vox(radii_vox),
        "added_void_vox": added_void_vox,
        "phi_image": float(segmented.mean()),
        "phi_abs": float(absolute_porosity(net)),
        f"phi_eff_{FLOW_AXIS}": float(effective_porosity(net, axis=FLOW_AXIS)),
        "K_axis_m2": kabs,
        "K_ratio_to_baseline": float(k_ratio),
        "Q_m3_s": float(res.total_flow_rate),
        "mass_balance_error": float(res.mass_balance_error),
        "Np": int(net.Np),
        "Nt": int(net.Nt),
        "mean_coordination": float(coordination.mean()),
        "mean_pore_size_um": float(1.0e6 * pore_size_m.mean()),
        "median_pore_size_um": float(1.0e6 * np.median(pore_size_m)),
        "pore_size_field": pore_size_field,
        "threshold_otsu": float(threshold),
    }
    diag = {
        "plotly": fig,
        "plotly_title": (
            f"B{baseline_id} | {case_name} | K{FLOW_AXIS}={kabs:.3e} m2 | "
            f"phi={float(segmented.mean()):.4f}"
        ),
        "net": net,
        "pore_pressure": np.asarray(res.pore_pressure, dtype=float),
        "pore_size_um": 1.0e6 * pore_size_m,
        "coordination": coordination,
        "segmented": segmented.astype(bool),
    }
    return row, diag

# %% [markdown]
# ## Define vug configuration templates
#
# Each configuration is applied to each of the baseline realizations.

# %%
vug_templates: list[dict[str, object]] = []

for i, r in enumerate(SPHERE_RADII_VOX, start=1):
    vug_templates.append(
        {
            "case": f"sphere_cfg{i}_r{r}",
            "family": "spherical",
            "orientation": "isotropic",
            "config_index": i,
            "radii": (r, r, r),
        }
    )

for i, radii in enumerate(ELLIPSOID_FLOW_RADII_VOX, start=1):
    vug_templates.append(
        {
            "case": f"ellipsoid_flow_cfg{i}_{radii[0]}_{radii[1]}_{radii[2]}",
            "family": "ellipsoidal",
            "orientation": "flow_stretched",
            "config_index": i,
            "radii": radii,
        }
    )

for i, radii in enumerate(ELLIPSOID_ORTH_RADII_VOX, start=1):
    vug_templates.append(
        {
            "case": f"ellipsoid_orth_cfg{i}_{radii[0]}_{radii[1]}_{radii[2]}",
            "family": "ellipsoidal",
            "orientation": "orthogonal_stretched",
            "config_index": i,
            "radii": radii,
        }
    )

print("Total vug templates:", len(vug_templates))
# Out:
# Total vug templates: 15

# %% [markdown]
# ## Generate independent baseline realizations
#
# We enforce percolation across the flow axis for each baseline.

# %%
baseline_images: dict[int, np.ndarray] = {}
baseline_seeds: dict[int, int] = {}

for baseline_id in iter_progress(
    range(1, N_BASELINES + 1),
    desc="Generating baseline realizations",
    total=N_BASELINES,
    enabled=USE_TQDM,
    leave=True,
):
    seed_start = BASE_SEED + 2000 * baseline_id
    baseline_void, used_seed = generate_connected_matrix(
        shape=SHAPE,
        porosity=TARGET_MATRIX_POROSITY,
        blobiness=BLOBINESS,
        axis_index=FLOW_AXIS_INDEX,
        seed_start=seed_start,
        max_tries=MAX_MATRIX_TRIES,
        show_progress=False,
        progress_desc=f"B{baseline_id}: spanning-seed search",
    )
    baseline_images[baseline_id] = baseline_void
    baseline_seeds[baseline_id] = used_seed

for baseline_id in baseline_images:
    print(
        f"baseline {baseline_id}: seed={baseline_seeds[baseline_id]}, "
        f"phi={float(baseline_images[baseline_id].mean()):.4f}, "
        f"spanning={has_spanning_cluster(baseline_images[baseline_id], FLOW_AXIS_INDEX)}"
    )
# Out:
# Generating baseline realizations: 100%|██████████| 30/30 [00:02<00:00, 12.99it/s]
# baseline 1: seed=20262307, phi=0.1500, spanning=True
# baseline 2: seed=20264305, phi=0.1500, spanning=True
# baseline 3: seed=20266311, phi=0.1500, spanning=True
# baseline 4: seed=20268309, phi=0.1500, spanning=True
# baseline 5: seed=20270306, phi=0.1500, spanning=True
# baseline 6: seed=20272309, phi=0.1500, spanning=True
# baseline 7: seed=20274311, phi=0.1500, spanning=True
# baseline 8: seed=20276309, phi=0.1500, spanning=True
# baseline 9: seed=20278306, phi=0.1500, spanning=True
# baseline 10: seed=20280306, phi=0.1500, spanning=True
# baseline 11: seed=20282305, phi=0.1500, spanning=True
# baseline 12: seed=20284309, phi=0.1500, spanning=True
# baseline 13: seed=20286305, phi=0.1500, spanning=True
# baseline 14: seed=20288306, phi=0.1500, spanning=True
# baseline 15: seed=20290305, phi=0.1500, spanning=True
# baseline 16: seed=20292306, phi=0.1500, spanning=True
# baseline 17: seed=20294307, phi=0.1500, spanning=True
# baseline 18: seed=20296305, phi=0.1500, spanning=True
# baseline 19: seed=20298305, phi=0.1500, spanning=True
# baseline 20: seed=20300309, phi=0.1500, spanning=True
# baseline 21: seed=20302305, phi=0.1500, spanning=True
# baseline 22: seed=20304305, phi=0.1500, spanning=True
# baseline 23: seed=20306311, phi=0.1500, spanning=True
# baseline 24: seed=20308307, phi=0.1500, spanning=True
# baseline 25: seed=20310305, phi=0.1500, spanning=True
# baseline 26: seed=20312310, phi=0.1500, spanning=True
# baseline 27: seed=20314305, phi=0.1500, spanning=True
# baseline 28: seed=20316305, phi=0.1500, spanning=True
# baseline 29: seed=20318307, phi=0.1500, spanning=True
# baseline 30: seed=20320306, phi=0.1500, spanning=True

# %%
mid_x = SHAPE[0] // 2
ncols = min(5, N_BASELINES)
nrows = (N_BASELINES + ncols - 1) // ncols
fig, axes = plt.subplots(
    nrows, ncols, figsize=(3.5 * ncols, 3.3 * nrows), squeeze=False
)

baseline_ids = sorted(baseline_images.keys())
for idx, baseline_id in enumerate(baseline_ids):
    row = idx // ncols
    col = idx % ncols
    ax = axes[row, col]
    ax.imshow(baseline_images[baseline_id][mid_x], cmap="gray", origin="lower")
    ax.set_title(f"B{baseline_id} (x={mid_x})")
    ax.set_xlabel("z")
    ax.set_ylabel("y")

for idx in range(len(baseline_ids), nrows * ncols):
    axes[idx // ncols, idx % ncols].axis("off")

fig.suptitle("Middle YZ slices for all baseline realizations")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Run all baseline + vug cases and solve flow
#
# Total number of cases:
#
# `N_BASELINES * (1 + N_spherical + N_ellipsoid_flow + N_ellipsoid_orth)`

# %%
all_results: list[dict[str, float | int | str]] = []
all_diagnostics: dict[str, dict[str, object]] = {}
case_void_images: dict[str, np.ndarray] = {}

HAS_DEBUG_PRINTS = False
baseline_id_iter = iter_progress(
    sorted(baseline_images.keys()),
    desc="Running baseline studies",
    total=len(baseline_images),
    enabled=USE_TQDM,
    leave=True,
)
for baseline_id in baseline_id_iter:
    baseline_void = baseline_images[baseline_id]

    # Baseline case first to define K0 for this realization
    baseline_case_name = f"B{baseline_id}_baseline"
    case_void_images[baseline_case_name] = baseline_void.copy()
    baseline_row, baseline_diag = evaluate_case(
        baseline_id=baseline_id,
        case_name=baseline_case_name,
        family="baseline",
        orientation="none",
        config_index=0,
        radii_vox=(0, 0, 0),
        binary_void=baseline_void,
        baseline_void=baseline_void,
        case_seed=BASE_SEED + 10000 + baseline_id,
        baseline_kabs=None,
    )
    baseline_kabs = float(baseline_row["K_axis_m2"])
    all_results.append(baseline_row)
    all_diagnostics[baseline_case_name] = baseline_diag

    if HAS_DEBUG_PRINTS:
        print(
            f"{baseline_case_name:>24s} | phi_image={baseline_row['phi_image']:.4f} | "
            f"K{FLOW_AXIS}={baseline_kabs:.3e} m^2"
        )

    # Vug cases for this baseline
    template_iter = iter_progress(
        list(enumerate(vug_templates, start=1)),
        desc=f"B{baseline_id}: vug configurations",
        total=len(vug_templates),
        enabled=USE_TQDM,
        leave=False,
    )
    for j, tpl in template_iter:
        case_root = str(tpl["case"])
        family = str(tpl["family"])
        orientation = str(tpl["orientation"])
        config_index = int(tpl["config_index"])
        radii = tuple(int(v) for v in tuple(tpl["radii"]))

        case_name = f"B{baseline_id}_{case_root}"
        if family == "spherical":
            case_void, _ = insert_spherical_vug(baseline_void, radius_vox=radii[0])
        else:
            case_void, _ = insert_ellipsoidal_vug(baseline_void, radii_vox=radii)
        case_void_images[case_name] = case_void.copy()

        row, diag = evaluate_case(
            baseline_id=baseline_id,
            case_name=case_name,
            family=family,
            orientation=orientation,
            config_index=config_index,
            radii_vox=radii,
            binary_void=case_void,
            baseline_void=baseline_void,
            case_seed=BASE_SEED + 20000 + 1000 * baseline_id + j,
            baseline_kabs=baseline_kabs,
        )
        all_results.append(row)
        all_diagnostics[case_name] = diag

        if HAS_DEBUG_PRINTS:
            print(
                f"{case_name:>24s} | phi_image={row['phi_image']:.4f} | "
                f"K{FLOW_AXIS}={row['K_axis_m2']:.3e} m^2 | "
                f"K/K0={row['K_ratio_to_baseline']:.3f}"
            )

print("Total solved cases:", len(all_results))
# Out:
# Running baseline studies: 100%|██████████| 30/30 [08:30<00:00, 17.01s/it]
# Total solved cases: 480

# %%
header = (
    f"{'case':<36} {'family':<11} {'orientation':<20} {'cfg':>3} "
    f"{'r_eq':>7} {'phi[%]':>8} {'K[m2]':>11} {'K/K0':>7} {'Np':>5} {'Nt':>6}"
)
print(header)
print("-" * len(header))

for row in all_results:
    print(
        f"{str(row['case']):<36} {str(row['family']):<11} {str(row['orientation']):<20} "
        f"{int(row['config_index']):>3d} {float(row['equivalent_radius_vox']):>7.2f} "
        f"{100.0 * float(row['phi_image']):>8.3f} {float(row['K_axis_m2']):>11.3e} "
        f"{float(row['K_ratio_to_baseline']):>7.3f} {int(row['Np']):>5d} {int(row['Nt']):>6d}"
    )
# Out:
# case                                 family      orientation          cfg    r_eq   phi[%]       K[m2]    K/K0    Np     Nt
# ---------------------------------------------------------------------------------------------------------------------------
# B1_baseline                          baseline    none                   0    0.00   15.000   4.106e-13   1.000   438    818
# B1_sphere_cfg1_r4                    spherical   isotropic              1    4.00   15.106   4.208e-13   1.025   453    841
# B1_sphere_cfg2_r6                    spherical   isotropic              2    6.00   15.375   4.071e-13   0.991   455    840
# B1_sphere_cfg3_r8                    spherical   isotropic              3    8.00   15.821   3.970e-13   0.967   452    838
# B1_sphere_cfg4_r10                   spherical   isotropic              4   10.00   16.597   4.120e-13   1.003   452    831
# B1_sphere_cfg5_r12                   spherical   isotropic              5   12.00   17.787   3.955e-13   0.963   441    813
# B1_ellipsoid_flow_cfg1_9_5_5         ellipsoidal flow_stretched         1    6.08   15.361   4.115e-13   1.002   454    835
# B1_ellipsoid_flow_cfg2_11_6_6        ellipsoidal flow_stretched         2    7.34   15.631   4.012e-13   0.977   453    842
# B1_ellipsoid_flow_cfg3_13_7_7        ellipsoidal flow_stretched         3    8.60   16.026   4.119e-13   1.003   449    828
# B1_ellipsoid_flow_cfg4_15_8_8        ellipsoidal flow_stretched         4    9.86   16.537   4.175e-13   1.017   442    814
# B1_ellipsoid_flow_cfg5_17_9_9        ellipsoidal flow_stretched         5   11.13   17.190   4.021e-13   0.979   445    818
# B1_ellipsoid_orth_cfg1_5_5_9         ellipsoidal orthogonal_stretched   1    6.08   15.363   4.103e-13   0.999   459    855
# B1_ellipsoid_orth_cfg2_6_6_11        ellipsoidal orthogonal_stretched   2    7.34   15.628   3.982e-13   0.970   450    833
# B1_ellipsoid_orth_cfg3_7_7_13        ellipsoidal orthogonal_stretched   3    8.60   16.037   4.021e-13   0.979   448    821
# B1_ellipsoid_orth_cfg4_8_8_15        ellipsoidal orthogonal_stretched   4    9.86   16.558   4.046e-13   0.985   445    813
# B1_ellipsoid_orth_cfg5_9_9_17        ellipsoidal orthogonal_stretched   5   11.13   17.223   3.945e-13   0.961   444    809
# B2_baseline                          baseline    none                   0    0.00   15.000   4.211e-13   1.000   424    871
# B2_sphere_cfg1_r4                    spherical   isotropic              1    4.00   15.093   4.343e-13   1.031   461    906
# B2_sphere_cfg2_r6                    spherical   isotropic              2    6.00   15.350   4.362e-13   1.036   463    907
# B2_sphere_cfg3_r8                    spherical   isotropic              3    8.00   15.806   4.415e-13   1.048   460    898
# B2_sphere_cfg4_r10                   spherical   isotropic              4   10.00   16.618   4.519e-13   1.073   454    894
# B2_sphere_cfg5_r12                   spherical   isotropic              5   12.00   17.778   4.647e-13   1.104   448    891
# B2_ellipsoid_flow_cfg1_9_5_5         ellipsoidal flow_stretched         1    6.08   15.367   4.484e-13   1.065   460    900
# B2_ellipsoid_flow_cfg2_11_6_6        ellipsoidal flow_stretched         2    7.34   15.643   4.403e-13   1.046   458    902
# B2_ellipsoid_flow_cfg3_13_7_7        ellipsoidal flow_stretched         3    8.60   16.026   4.453e-13   1.057   453    891
# B2_ellipsoid_flow_cfg4_15_8_8        ellipsoidal flow_stretched         4    9.86   16.540   4.809e-13   1.142   452    894
# B2_ellipsoid_flow_cfg5_17_9_9        ellipsoidal flow_stretched         5   11.13   17.219   4.607e-13   1.094   452    887
# B2_ellipsoid_orth_cfg1_5_5_9         ellipsoidal orthogonal_stretched   1    6.08   15.335   4.191e-13   0.995   459    896
# B2_ellipsoid_orth_cfg2_6_6_11        ellipsoidal orthogonal_stretched   2    7.34   15.594   4.337e-13   1.030   460    907
# B2_ellipsoid_orth_cfg3_7_7_13        ellipsoidal orthogonal_stretched   3    8.60   15.985   4.387e-13   1.042   458    902
# B2_ellipsoid_orth_cfg4_8_8_15        ellipsoidal orthogonal_stretched   4    9.86   16.532   4.451e-13   1.057   451    897
# B2_ellipsoid_orth_cfg5_9_9_17        ellipsoidal orthogonal_stretched   5   11.13   17.249   4.429e-13   1.052   449    886
# B3_baseline                          baseline    none                   0    0.00   14.999   9.072e-13   1.000   408    866
# B3_sphere_cfg1_r4                    spherical   isotropic              1    4.00   15.094   7.476e-13   0.824   437    902
# B3_sphere_cfg2_r6                    spherical   isotropic              2    6.00   15.350   7.266e-13   0.801   443    910
# B3_sphere_cfg3_r8                    spherical   isotropic              3    8.00   15.835   7.332e-13   0.808   439    912
# B3_sphere_cfg4_r10                   spherical   isotropic              4   10.00   16.656   7.193e-13   0.793   435    888
# B3_sphere_cfg5_r12                   spherical   isotropic              5   12.00   17.822   7.916e-13   0.873   425    870
# B3_ellipsoid_flow_cfg1_9_5_5         ellipsoidal flow_stretched         1    6.08   15.372   7.760e-13   0.855   435    908
# B3_ellipsoid_flow_cfg2_11_6_6        ellipsoidal flow_stretched         2    7.34   15.649   7.682e-13   0.847   439    909
# B3_ellipsoid_flow_cfg3_13_7_7        ellipsoidal flow_stretched         3    8.60   16.070   7.272e-13   0.802   438    901
# B3_ellipsoid_flow_cfg4_15_8_8        ellipsoidal flow_stretched         4    9.86   16.614   7.703e-13   0.849   434    892
# B3_ellipsoid_flow_cfg5_17_9_9        ellipsoidal flow_stretched         5   11.13   17.282   7.447e-13   0.821   428    876
# B3_ellipsoid_orth_cfg1_5_5_9         ellipsoidal orthogonal_stretched   1    6.08   15.355   7.380e-13   0.813   440    912
# B3_ellipsoid_orth_cfg2_6_6_11        ellipsoidal orthogonal_stretched   2    7.34   15.639   7.405e-13   0.816   445    911
# B3_ellipsoid_orth_cfg3_7_7_13        ellipsoidal orthogonal_stretched   3    8.60   16.060   7.689e-13   0.847   437    906
# B3_ellipsoid_orth_cfg4_8_8_15        ellipsoidal orthogonal_stretched   4    9.86   16.598   7.603e-13   0.838   431    893
# B3_ellipsoid_orth_cfg5_9_9_17        ellipsoidal orthogonal_stretched   5   11.13   17.267   7.624e-13   0.840   430    886
# B4_baseline                          baseline    none                   0    0.00   15.000   3.707e-13   1.000   402    779
# B4_sphere_cfg1_r4                    spherical   isotropic              1    4.00   15.109   4.669e-13   1.260   430    810
# B4_sphere_cfg2_r6                    spherical   isotropic              2    6.00   15.380   3.994e-13   1.078   434    817
# B4_sphere_cfg3_r8                    spherical   isotropic              3    8.00   15.845   3.968e-13   1.070   432    821
# B4_sphere_cfg4_r10                   spherical   isotropic              4   10.00   16.650   4.011e-13   1.082   432    825
# B4_sphere_cfg5_r12                   spherical   isotropic              5   12.00   17.808   4.226e-13   1.140   424    808
# B4_ellipsoid_flow_cfg1_9_5_5         ellipsoidal flow_stretched         1    6.08   15.367   4.093e-13   1.104   428    814
# B4_ellipsoid_flow_cfg2_11_6_6        ellipsoidal flow_stretched         2    7.34   15.646   4.010e-13   1.082   432    819
# B4_ellipsoid_flow_cfg3_13_7_7        ellipsoidal flow_stretched         3    8.60   16.032   4.286e-13   1.156   435    818
# B4_ellipsoid_flow_cfg4_15_8_8        ellipsoidal flow_stretched         4    9.86   16.556   4.625e-13   1.248   430    816
# B4_ellipsoid_flow_cfg5_17_9_9        ellipsoidal flow_stretched         5   11.13   17.251   4.249e-13   1.146   426    820
# B4_ellipsoid_orth_cfg1_5_5_9         ellipsoidal orthogonal_stretched   1    6.08   15.396   4.002e-13   1.080   429    817
# B4_ellipsoid_orth_cfg2_6_6_11        ellipsoidal orthogonal_stretched   2    7.34   15.680   3.974e-13   1.072   430    817
# B4_ellipsoid_orth_cfg3_7_7_13        ellipsoidal orthogonal_stretched   3    8.60   16.079   4.022e-13   1.085   436    819
# B4_ellipsoid_orth_cfg4_8_8_15        ellipsoidal orthogonal_stretched   4    9.86   16.622   3.984e-13   1.075   431    823
# B4_ellipsoid_orth_cfg5_9_9_17        ellipsoidal orthogonal_stretched   5   11.13   17.302   3.994e-13   1.077   430    816
# B5_baseline                          baseline    none                   0    0.00   15.000   5.230e-13   1.000   432    857
# B5_sphere_cfg1_r4                    spherical   isotropic              1    4.00   15.098   4.953e-13   0.947   448    869
# B5_sphere_cfg2_r6                    spherical   isotropic              2    6.00   15.350   4.621e-13   0.883   456    880
# B5_sphere_cfg3_r8                    spherical   isotropic              3    8.00   15.790   4.212e-13   0.805   453    863
# B5_sphere_cfg4_r10                   spherical   isotropic              4   10.00   16.557   4.157e-13   0.795   451    849
# B5_sphere_cfg5_r12                   spherical   isotropic              5   12.00   17.723   4.705e-13   0.900   440    828
# B5_ellipsoid_flow_cfg1_9_5_5         ellipsoidal flow_stretched         1    6.08   15.354   4.721e-13   0.903   449    870
# B5_ellipsoid_flow_cfg2_11_6_6        ellipsoidal flow_stretched         2    7.34   15.616   4.526e-13   0.865   453    857
# B5_ellipsoid_flow_cfg3_13_7_7        ellipsoidal flow_stretched         3    8.60   16.002   4.521e-13   0.864   449    854
# B5_ellipsoid_flow_cfg4_15_8_8        ellipsoidal flow_stretched         4    9.86   16.512   4.309e-13   0.824   443    832
# B5_ellipsoid_flow_cfg5_17_9_9        ellipsoidal flow_stretched         5   11.13   17.167   5.067e-13   0.969   440    825
# B5_ellipsoid_orth_cfg1_5_5_9         ellipsoidal orthogonal_stretched   1    6.08   15.361   4.563e-13   0.872   452    876
# B5_ellipsoid_orth_cfg2_6_6_11        ellipsoidal orthogonal_stretched   2    7.34   15.626   4.581e-13   0.876   451    859
# B5_ellipsoid_orth_cfg3_7_7_13        ellipsoidal orthogonal_stretched   3    8.60   16.026   4.495e-13   0.859   448    859
# B5_ellipsoid_orth_cfg4_8_8_15        ellipsoidal orthogonal_stretched   4    9.86   16.534   4.205e-13   0.804   448    849
# B5_ellipsoid_orth_cfg5_9_9_17        ellipsoidal orthogonal_stretched   5   11.13   17.194   4.817e-13   0.921   448    849
# B6_baseline                          baseline    none                   0    0.00   15.000   5.339e-13   1.000   421    900
# B6_sphere_cfg1_r4                    spherical   isotropic              1    4.00   15.090   5.027e-13   0.942   444    917
# B6_sphere_cfg2_r6                    spherical   isotropic              2    6.00   15.341   4.977e-13   0.932   455    933
# B6_sphere_cfg3_r8                    spherical   isotropic              3    8.00   15.785   5.613e-13   1.051   454    940
# B6_sphere_cfg4_r10                   spherical   isotropic              4   10.00   16.594   5.508e-13   1.032   442    923
# B6_sphere_cfg5_r12                   spherical   isotropic              5   12.00   17.748   5.709e-13   1.069   433    891
# B6_ellipsoid_flow_cfg1_9_5_5         ellipsoidal flow_stretched         1    6.08   15.352   4.994e-13   0.935   447    915
# B6_ellipsoid_flow_cfg2_11_6_6        ellipsoidal flow_stretched         2    7.34   15.612   4.967e-13   0.930   449    923
# B6_ellipsoid_flow_cfg3_13_7_7        ellipsoidal flow_stretched         3    8.60   15.992   4.933e-13   0.924   449    934
# B6_ellipsoid_flow_cfg4_15_8_8        ellipsoidal flow_stretched         4    9.86   16.502   5.653e-13   1.059   446    924
# B6_ellipsoid_flow_cfg5_17_9_9        ellipsoidal flow_stretched         5   11.13   17.185   5.889e-13   1.103   435    891
# B6_ellipsoid_orth_cfg1_5_5_9         ellipsoidal orthogonal_stretched   1    6.08   15.335   4.847e-13   0.908   452    925
# B6_ellipsoid_orth_cfg2_6_6_11        ellipsoidal orthogonal_stretched   2    7.34   15.601   4.955e-13   0.928   455    931
# B6_ellipsoid_orth_cfg3_7_7_13        ellipsoidal orthogonal_stretched   3    8.60   15.996   5.171e-13   0.968   451    931
# B6_ellipsoid_orth_cfg4_8_8_15        ellipsoidal orthogonal_stretched   4    9.86   16.536   5.671e-13   1.062   438    900
# B6_ellipsoid_orth_cfg5_9_9_17        ellipsoidal orthogonal_stretched   5   11.13   17.220   5.507e-13   1.031   434    892
# B7_baseline                          baseline    none                   0    0.00   15.000   4.806e-13   1.000   433    820
# B7_sphere_cfg1_r4                    spherical   isotropic              1    4.00   15.094   4.663e-13   0.970   448    846
# B7_sphere_cfg2_r6                    spherical   isotropic              2    6.00   15.364   4.329e-13   0.901   456    845
# B7_sphere_cfg3_r8                    spherical   isotropic              3    8.00   15.837   4.489e-13   0.934   454    840
# B7_sphere_cfg4_r10                   spherical   isotropic              4   10.00   16.646   4.540e-13   0.945   447    832
# B7_sphere_cfg5_r12                   spherical   isotropic              5   12.00   17.822   4.936e-13   1.027   443    830
# B7_ellipsoid_flow_cfg1_9_5_5         ellipsoidal flow_stretched         1    6.08   15.369   4.565e-13   0.950   448    835
# B7_ellipsoid_flow_cfg2_11_6_6        ellipsoidal flow_stretched         2    7.34   15.656   4.593e-13   0.956   454    840
# B7_ellipsoid_flow_cfg3_13_7_7        ellipsoidal flow_stretched         3    8.60   16.049   4.570e-13   0.951   454    845
# B7_ellipsoid_flow_cfg4_15_8_8        ellipsoidal flow_stretched         4    9.86   16.563   5.191e-13   1.080   453    841
# B7_ellipsoid_flow_cfg5_17_9_9        ellipsoidal flow_stretched         5   11.13   17.265   5.063e-13   1.053   444    826
# B7_ellipsoid_orth_cfg1_5_5_9         ellipsoidal orthogonal_stretched   1    6.08   15.365   4.466e-13   0.929   450    836
# B7_ellipsoid_orth_cfg2_6_6_11        ellipsoidal orthogonal_stretched   2    7.34   15.641   4.250e-13   0.884   454    838
# B7_ellipsoid_orth_cfg3_7_7_13        ellipsoidal orthogonal_stretched   3    8.60   16.036   4.637e-13   0.965   450    835
# B7_ellipsoid_orth_cfg4_8_8_15        ellipsoidal orthogonal_stretched   4    9.86   16.573   4.397e-13   0.915   452    826
# B7_ellipsoid_orth_cfg5_9_9_17        ellipsoidal orthogonal_stretched   5   11.13   17.269   4.687e-13   0.975   443    835
# B8_baseline                          baseline    none                   0    0.00   15.000   4.736e-13   1.000   421    839
# B8_sphere_cfg1_r4                    spherical   isotropic              1    4.00   15.103   5.042e-13   1.065   457    889
# B8_sphere_cfg2_r6                    spherical   isotropic              2    6.00   15.370   4.709e-13   0.994   468    920
# B8_sphere_cfg3_r8                    spherical   isotropic              3    8.00   15.836   5.248e-13   1.108   459    905
# B8_sphere_cfg4_r10                   spherical   isotropic              4   10.00   16.619   5.243e-13   1.107   448    878
# B8_sphere_cfg5_r12                   spherical   isotropic              5   12.00   17.742   5.323e-13   1.124   440    847
# B8_ellipsoid_flow_cfg1_9_5_5         ellipsoidal flow_stretched         1    6.08   15.387   4.888e-13   1.032   460    902
# B8_ellipsoid_flow_cfg2_11_6_6        ellipsoidal flow_stretched         2    7.34   15.659   5.291e-13   1.117   463    916
# B8_ellipsoid_flow_cfg3_13_7_7        ellipsoidal flow_stretched         3    8.60   16.044   5.295e-13   1.118   452    892
# B8_ellipsoid_flow_cfg4_15_8_8        ellipsoidal flow_stretched         4    9.86   16.549   5.167e-13   1.091   449    883
# B8_ellipsoid_flow_cfg5_17_9_9        ellipsoidal flow_stretched         5   11.13   17.208   5.363e-13   1.132   441    857
# B8_ellipsoid_orth_cfg1_5_5_9         ellipsoidal orthogonal_stretched   1    6.08   15.382   4.992e-13   1.054   459    909
# B8_ellipsoid_orth_cfg2_6_6_11        ellipsoidal orthogonal_stretched   2    7.34   15.654   4.859e-13   1.026   460    899
# B8_ellipsoid_orth_cfg3_7_7_13        ellipsoidal orthogonal_stretched   3    8.60   16.050   5.422e-13   1.145   457    897
# B8_ellipsoid_orth_cfg4_8_8_15        ellipsoidal orthogonal_stretched   4    9.86   16.550   5.026e-13   1.061   450    884
# B8_ellipsoid_orth_cfg5_9_9_17        ellipsoidal orthogonal_stretched   5   11.13   17.203   5.073e-13   1.071   449    875
# B9_baseline                          baseline    none                   0    0.00   14.999   3.808e-13   1.000   404    850
# B9_sphere_cfg1_r4                    spherical   isotropic              1    4.00   15.105   3.882e-13   1.019   419    868
# B9_sphere_cfg2_r6                    spherical   isotropic              2    6.00   15.369   3.749e-13   0.984   435    885
# B9_sphere_cfg3_r8                    spherical   isotropic              3    8.00   15.831   3.856e-13   1.013   426    876
# B9_sphere_cfg4_r10                   spherical   isotropic              4   10.00   16.638   3.771e-13   0.990   424    874
# B9_sphere_cfg5_r12                   spherical   isotropic              5   12.00   17.822   3.771e-13   0.990   416    857
# B9_ellipsoid_flow_cfg1_9_5_5         ellipsoidal flow_stretched         1    6.08   15.381   4.017e-13   1.055   425    877
# B9_ellipsoid_flow_cfg2_11_6_6        ellipsoidal flow_stretched         2    7.34   15.654   3.686e-13   0.968   432    888
# B9_ellipsoid_flow_cfg3_13_7_7        ellipsoidal flow_stretched         3    8.60   16.054   3.703e-13   0.973   427    882
# B9_ellipsoid_flow_cfg4_15_8_8        ellipsoidal flow_stretched         4    9.86   16.588   3.803e-13   0.999   423    864
# B9_ellipsoid_flow_cfg5_17_9_9        ellipsoidal flow_stretched         5   11.13   17.281   3.861e-13   1.014   419    866
# B9_ellipsoid_orth_cfg1_5_5_9         ellipsoidal orthogonal_stretched   1    6.08   15.361   3.952e-13   1.038   424    871
# B9_ellipsoid_orth_cfg2_6_6_11        ellipsoidal orthogonal_stretched   2    7.34   15.629   3.963e-13   1.041   422    872
# B9_ellipsoid_orth_cfg3_7_7_13        ellipsoidal orthogonal_stretched   3    8.60   16.037   3.795e-13   0.997   428    878
# B9_ellipsoid_orth_cfg4_8_8_15        ellipsoidal orthogonal_stretched   4    9.86   16.572   3.752e-13   0.985   421    860
# B9_ellipsoid_orth_cfg5_9_9_17        ellipsoidal orthogonal_stretched   5   11.13   17.266   3.813e-13   1.001   417    855
# B10_baseline                         baseline    none                   0    0.00   15.000   4.697e-13   1.000   448    863
# B10_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.108   3.660e-13   0.779   466    883
# B10_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.372   3.825e-13   0.814   463    874
# B10_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.835   3.794e-13   0.808   463    869
# B10_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.671   3.845e-13   0.819   451    852
# B10_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.840   3.947e-13   0.840   441    825
# B10_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.385   3.852e-13   0.820   463    878
# B10_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.656   3.880e-13   0.826   459    869
# B10_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.062   3.851e-13   0.820   456    857
# B10_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.583   3.858e-13   0.821   457    855
# B10_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.279   3.903e-13   0.831   450    852
# B10_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.374   3.835e-13   0.817   462    881
# B10_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.656   3.794e-13   0.808   463    867
# B10_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.053   3.865e-13   0.823   454    862
# B10_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.594   3.916e-13   0.834   456    863
# B10_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.287   3.938e-13   0.838   449    848
# B11_baseline                         baseline    none                   0    0.00   15.000   5.104e-13   1.000   398    843
# B11_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.098   4.392e-13   0.860   427    851
# B11_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.350   4.498e-13   0.881   426    858
# B11_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.793   4.537e-13   0.889   426    851
# B11_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.572   4.547e-13   0.891   423    850
# B11_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.748   4.529e-13   0.887   408    815
# B11_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.348   4.722e-13   0.925   428    861
# B11_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.605   4.611e-13   0.903   425    849
# B11_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   15.992   4.326e-13   0.848   426    849
# B11_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.500   4.598e-13   0.901   421    849
# B11_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.197   4.405e-13   0.863   418    843
# B11_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.365   4.532e-13   0.888   429    863
# B11_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.634   4.566e-13   0.895   428    858
# B11_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.029   4.520e-13   0.886   424    852
# B11_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.542   4.652e-13   0.911   419    842
# B11_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.197   4.427e-13   0.867   414    818
# B12_baseline                         baseline    none                   0    0.00   15.000   8.772e-13   1.000   417    888
# B12_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.092   8.803e-13   1.004   440    937
# B12_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.339   8.586e-13   0.979   448    941
# B12_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.794   8.839e-13   1.008   445    947
# B12_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.609   8.478e-13   0.967   440    936
# B12_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.821   8.534e-13   0.973   432    899
# B12_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.336   8.530e-13   0.972   444    939
# B12_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.601   8.754e-13   0.998   444    939
# B12_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   15.997   8.829e-13   1.007   440    917
# B12_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.539   8.954e-13   1.021   438    921
# B12_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.241   9.611e-13   1.096   432    916
# B12_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.349   8.345e-13   0.951   441    936
# B12_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.627   8.414e-13   0.959   445    945
# B12_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.037   8.494e-13   0.968   440    936
# B12_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.568   8.336e-13   0.950   437    916
# B12_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.249   8.240e-13   0.939   435    913
# B13_baseline                         baseline    none                   0    0.00   15.000   6.805e-13   1.000   429    886
# B13_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.104   6.450e-13   0.948   445    889
# B13_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.356   6.385e-13   0.938   452    904
# B13_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.802   6.110e-13   0.898   454    899
# B13_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.599   6.201e-13   0.911   446    877
# B13_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.745   6.344e-13   0.932   438    860
# B13_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.351   6.352e-13   0.933   450    892
# B13_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.604   6.440e-13   0.946   446    889
# B13_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   15.980   6.141e-13   0.902   451    890
# B13_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.496   6.337e-13   0.931   448    878
# B13_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.168   6.448e-13   0.948   443    869
# B13_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.378   6.329e-13   0.930   451    895
# B13_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.651   6.178e-13   0.908   444    886
# B13_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.035   6.160e-13   0.905   452    893
# B13_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.544   6.326e-13   0.930   449    881
# B13_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.214   6.286e-13   0.924   443    860
# B14_baseline                         baseline    none                   0    0.00   15.000   3.830e-13   1.000   414    860
# B14_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.101   4.972e-13   1.298   427    884
# B14_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.363   4.940e-13   1.290   443    918
# B14_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.806   5.358e-13   1.399   441    901
# B14_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.585   5.109e-13   1.334   435    896
# B14_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.731   5.157e-13   1.347   422    865
# B14_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.375   5.587e-13   1.459   436    905
# B14_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.650   5.103e-13   1.333   438    913
# B14_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.055   5.418e-13   1.415   436    902
# B14_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.581   5.159e-13   1.347   430    876
# B14_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.219   5.192e-13   1.356   426    861
# B14_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.366   5.287e-13   1.381   434    900
# B14_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.628   4.992e-13   1.303   438    909
# B14_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.012   5.211e-13   1.361   437    893
# B14_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.514   5.213e-13   1.361   432    881
# B14_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.186   5.224e-13   1.364   427    872
# B15_baseline                         baseline    none                   0    0.00   15.000   4.529e-13   1.000   411    837
# B15_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.107   3.869e-13   0.854   434    883
# B15_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.386   5.470e-13   1.208   448    891
# B15_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.852   5.229e-13   1.154   439    873
# B15_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.660   5.391e-13   1.190   432    845
# B15_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.821   5.533e-13   1.222   419    824
# B15_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.383   5.503e-13   1.215   444    877
# B15_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.658   5.483e-13   1.211   443    876
# B15_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.049   5.471e-13   1.208   436    857
# B15_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.579   5.349e-13   1.181   430    842
# B15_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.241   5.689e-13   1.256   424    829
# B15_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.377   5.646e-13   1.247   443    893
# B15_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.666   5.373e-13   1.186   448    884
# B15_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.080   5.342e-13   1.179   437    866
# B15_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.616   5.254e-13   1.160   433    850
# B15_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.275   5.306e-13   1.172   432    849
# B16_baseline                         baseline    none                   0    0.00   15.000   6.277e-13   1.000   407    883
# B16_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.112   6.742e-13   1.074   433    919
# B16_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.387   6.955e-13   1.108   436    918
# B16_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.863   6.436e-13   1.025   438    905
# B16_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.695   6.718e-13   1.070   436    902
# B16_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.900   6.904e-13   1.100   429    884
# B16_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.397   6.828e-13   1.088   433    915
# B16_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.669   7.135e-13   1.137   431    904
# B16_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.072   7.095e-13   1.130   433    893
# B16_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.608   7.069e-13   1.126   431    895
# B16_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.321   6.657e-13   1.061   432    895
# B16_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.390   6.946e-13   1.107   432    916
# B16_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.677   7.135e-13   1.137   434    910
# B16_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.086   6.878e-13   1.096   436    908
# B16_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.634   6.892e-13   1.098   435    904
# B16_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.349   6.892e-13   1.098   432    904
# B17_baseline                         baseline    none                   0    0.00   15.000   3.859e-13   1.000   419    856
# B17_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.108   3.422e-13   0.887   449    896
# B17_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.388   3.487e-13   0.904   455    901
# B17_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.838   3.480e-13   0.902   446    883
# B17_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.643   3.489e-13   0.904   442    879
# B17_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.843   3.477e-13   0.901   435    848
# B17_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.386   3.474e-13   0.900   457    906
# B17_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.672   3.481e-13   0.902   447    894
# B17_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.072   3.606e-13   0.934   449    881
# B17_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.581   3.453e-13   0.895   438    869
# B17_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.229   3.574e-13   0.926   433    856
# B17_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.384   3.459e-13   0.896   456    908
# B17_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.675   3.517e-13   0.911   447    887
# B17_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.088   3.495e-13   0.906   450    884
# B17_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.613   3.512e-13   0.910   450    880
# B17_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.316   3.452e-13   0.894   439    862
# B18_baseline                         baseline    none                   0    0.00   15.000   5.177e-13   1.000   425    796
# B18_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.092   4.603e-13   0.889   450    819
# B18_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.348   4.904e-13   0.947   460    823
# B18_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.825   4.470e-13   0.864   457    810
# B18_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.652   4.722e-13   0.912   448    806
# B18_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.831   4.983e-13   0.963   440    791
# B18_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.363   4.619e-13   0.892   455    808
# B18_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.640   4.731e-13   0.914   451    800
# B18_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.049   4.732e-13   0.914   456    811
# B18_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.577   4.880e-13   0.943   451    810
# B18_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.254   5.315e-13   1.027   443    795
# B18_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.351   4.602e-13   0.889   455    811
# B18_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.620   4.719e-13   0.912   458    817
# B18_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.037   4.506e-13   0.870   460    812
# B18_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.570   4.593e-13   0.887   450    810
# B18_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.265   4.646e-13   0.898   445    793
# B19_baseline                         baseline    none                   0    0.00   15.000   6.690e-13   1.000   416    874
# B19_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.105   5.707e-13   0.853   434    898
# B19_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.352   5.518e-13   0.825   432    884
# B19_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.787   5.243e-13   0.784   440    892
# B19_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.583   5.609e-13   0.838   433    881
# B19_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.771   5.788e-13   0.865   424    859
# B19_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.354   5.798e-13   0.867   436    884
# B19_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.613   5.341e-13   0.798   433    890
# B19_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   15.995   5.550e-13   0.830   436    895
# B19_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.502   5.831e-13   0.872   431    879
# B19_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.154   6.010e-13   0.898   428    876
# B19_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.365   5.427e-13   0.811   437    879
# B19_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.624   5.585e-13   0.835   433    886
# B19_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.012   5.665e-13   0.847   438    898
# B19_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.533   5.574e-13   0.833   434    887
# B19_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.215   5.476e-13   0.819   426    866
# B20_baseline                         baseline    none                   0    0.00   15.000   5.356e-13   1.000   405    846
# B20_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.098   5.407e-13   1.010   429    861
# B20_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.358   5.690e-13   1.063   443    890
# B20_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.842   5.296e-13   0.989   435    878
# B20_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.637   5.389e-13   1.006   424    864
# B20_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.756   5.795e-13   1.082   418    849
# B20_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.370   5.403e-13   1.009   434    869
# B20_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.646   5.608e-13   1.047   437    876
# B20_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.034   5.699e-13   1.064   434    869
# B20_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.549   5.731e-13   1.070   433    877
# B20_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.215   5.899e-13   1.102   427    869
# B20_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.358   5.201e-13   0.971   433    875
# B20_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.634   5.619e-13   1.049   439    885
# B20_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.047   5.304e-13   0.990   431    874
# B20_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.583   5.518e-13   1.030   429    872
# B20_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.259   5.528e-13   1.032   425    855
# B21_baseline                         baseline    none                   0    0.00   15.000   4.073e-13   1.000   421    859
# B21_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.100   4.412e-13   1.083   435    870
# B21_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.371   4.256e-13   1.045   441    879
# B21_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.851   4.351e-13   1.068   430    855
# B21_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.649   4.515e-13   1.109   421    834
# B21_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.770   4.505e-13   1.106   416    809
# B21_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.379   4.441e-13   1.090   437    869
# B21_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.650   4.344e-13   1.067   436    863
# B21_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.056   4.204e-13   1.032   433    846
# B21_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.582   4.515e-13   1.109   422    839
# B21_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.262   4.517e-13   1.109   419    823
# B21_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.370   4.814e-13   1.182   436    875
# B21_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.655   4.322e-13   1.061   438    867
# B21_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.075   4.525e-13   1.111   431    850
# B21_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.594   4.298e-13   1.055   419    830
# B21_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.268   4.374e-13   1.074   414    809
# B22_baseline                         baseline    none                   0    0.00   15.000   5.774e-13   1.000   417    877
# B22_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.100   5.419e-13   0.939   448    928
# B22_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.363   5.103e-13   0.884   451    906
# B22_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.822   4.962e-13   0.859   452    902
# B22_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.643   5.102e-13   0.884   444    890
# B22_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.857   5.207e-13   0.902   431    856
# B22_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.371   5.112e-13   0.885   451    907
# B22_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.662   5.002e-13   0.866   449    894
# B22_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.063   5.326e-13   0.922   448    895
# B22_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.591   5.394e-13   0.934   442    886
# B22_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.281   5.227e-13   0.905   440    876
# B22_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.358   4.985e-13   0.863   453    911
# B22_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.631   5.025e-13   0.870   449    899
# B22_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.027   4.932e-13   0.854   446    891
# B22_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.545   5.098e-13   0.883   443    885
# B22_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.230   5.086e-13   0.881   438    865
# B23_baseline                         baseline    none                   0    0.00   15.000   5.841e-13   1.000   393    818
# B23_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.108   5.129e-13   0.878   418    833
# B23_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.354   5.524e-13   0.946   423    833
# B23_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.790   5.549e-13   0.950   420    844
# B23_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.596   5.715e-13   0.978   413    822
# B23_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.781   5.778e-13   0.989   402    798
# B23_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.360   5.674e-13   0.971   420    833
# B23_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.634   5.485e-13   0.939   420    827
# B23_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.011   5.975e-13   1.023   409    817
# B23_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.534   5.797e-13   0.992   413    825
# B23_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.191   5.808e-13   0.995   409    802
# B23_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.361   5.455e-13   0.934   419    830
# B23_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.624   5.626e-13   0.963   417    829
# B23_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   15.994   5.658e-13   0.969   414    829
# B23_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.508   5.511e-13   0.944   415    825
# B23_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.199   5.574e-13   0.954   411    817
# B24_baseline                         baseline    none                   0    0.00   15.000   5.073e-13   1.000   429    819
# B24_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.105   4.059e-13   0.800   449    852
# B24_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.380   4.834e-13   0.953   455    855
# B24_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.861   4.878e-13   0.961   451    844
# B24_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.645   4.853e-13   0.956   451    841
# B24_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.825   5.349e-13   1.054   444    828
# B24_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.389   3.997e-13   0.788   450    848
# B24_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.667   4.943e-13   0.974   448    840
# B24_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.071   5.050e-13   0.995   447    838
# B24_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.604   5.275e-13   1.040   446    833
# B24_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.289   5.319e-13   1.048   444    830
# B24_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.381   3.966e-13   0.782   453    854
# B24_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.670   4.845e-13   0.955   453    852
# B24_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.075   4.782e-13   0.943   449    841
# B24_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.604   4.838e-13   0.954   451    843
# B24_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.300   4.846e-13   0.955   443    833
# B25_baseline                         baseline    none                   0    0.00   15.000   3.580e-13   1.000   453    912
# B25_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.096   3.752e-13   1.048   473    931
# B25_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.330   3.406e-13   0.951   480    941
# B25_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.787   3.371e-13   0.942   477    944
# B25_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.583   3.468e-13   0.969   469    929
# B25_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.754   3.567e-13   0.996   466    921
# B25_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.341   3.298e-13   0.921   478    932
# B25_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.619   3.495e-13   0.976   474    926
# B25_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.010   3.629e-13   1.014   477    940
# B25_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.537   3.604e-13   1.007   473    942
# B25_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.205   3.955e-13   1.105   470    929
# B25_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.330   3.540e-13   0.989   471    925
# B25_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.592   3.401e-13   0.950   480    940
# B25_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   15.987   3.482e-13   0.973   476    925
# B25_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.503   3.466e-13   0.968   471    923
# B25_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.181   3.815e-13   1.066   469    925
# B26_baseline                         baseline    none                   0    0.00   15.000   6.441e-13   1.000   413    859
# B26_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.106   6.854e-13   1.064   443    898
# B26_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.367   5.541e-13   0.860   447    909
# B26_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.820   6.428e-13   0.998   442    898
# B26_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.613   6.409e-13   0.995   439    890
# B26_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.770   6.349e-13   0.986   434    891
# B26_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.360   6.362e-13   0.988   448    915
# B26_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.630   5.741e-13   0.891   449    914
# B26_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.032   6.322e-13   0.982   441    900
# B26_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.557   6.434e-13   0.999   440    894
# B26_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.239   6.781e-13   1.053   433    870
# B26_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.381   6.699e-13   1.040   449    911
# B26_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.644   5.701e-13   0.885   443    903
# B26_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.031   6.609e-13   1.026   441    901
# B26_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.554   6.332e-13   0.983   434    879
# B26_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.231   6.420e-13   0.997   433    884
# B27_baseline                         baseline    none                   0    0.00   15.000   4.499e-13   1.000   430    870
# B27_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.106   4.155e-13   0.924   449    883
# B27_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.365   3.958e-13   0.880   459    881
# B27_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.822   4.079e-13   0.907   457    882
# B27_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.638   4.201e-13   0.934   451    865
# B27_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.775   4.296e-13   0.955   442    848
# B27_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.362   4.085e-13   0.908   450    873
# B27_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.643   3.979e-13   0.884   461    883
# B27_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.053   4.220e-13   0.938   453    863
# B27_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.565   4.345e-13   0.966   448    865
# B27_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.219   4.228e-13   0.940   446    854
# B27_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.373   4.151e-13   0.923   450    880
# B27_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.650   3.979e-13   0.884   459    882
# B27_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.025   4.142e-13   0.921   453    870
# B27_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.531   4.200e-13   0.934   451    868
# B27_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.222   4.190e-13   0.931   446    848
# B28_baseline                         baseline    none                   0    0.00   15.000   5.589e-13   1.000   412    822
# B28_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.113   5.386e-13   0.964   433    858
# B28_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.383   5.230e-13   0.936   449    869
# B28_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.856   5.592e-13   1.001   443    858
# B28_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.649   5.887e-13   1.053   438    845
# B28_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.788   5.669e-13   1.014   430    824
# B28_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.392   5.419e-13   0.970   444    866
# B28_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.665   5.774e-13   1.033   442    859
# B28_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.062   5.987e-13   1.071   441    863
# B28_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.598   5.791e-13   1.036   441    846
# B28_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.277   6.044e-13   1.081   437    837
# B28_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.377   5.546e-13   0.992   440    856
# B28_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.655   5.340e-13   0.956   447    865
# B28_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.063   5.473e-13   0.979   444    853
# B28_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.589   5.594e-13   1.001   439    837
# B28_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.225   5.810e-13   1.040   432    824
# B29_baseline                         baseline    none                   0    0.00   15.000   6.234e-13   1.000   424    901
# B29_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.109   6.191e-13   0.993   457    962
# B29_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.368   6.493e-13   1.041   449    960
# B29_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.846   6.387e-13   1.024   455    967
# B29_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.607   6.386e-13   1.024   449    956
# B29_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.746   6.318e-13   1.013   447    937
# B29_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.376   6.237e-13   1.000   451    958
# B29_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.645   6.506e-13   1.044   448    961
# B29_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.060   6.811e-13   1.092   449    957
# B29_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.575   6.727e-13   1.079   446    939
# B29_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.231   6.827e-13   1.095   447    937
# B29_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.375   6.321e-13   1.014   450    964
# B29_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.640   6.533e-13   1.048   445    959
# B29_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.040   6.790e-13   1.089   447    949
# B29_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.562   6.356e-13   1.020   450    930
# B29_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.214   6.355e-13   1.019   442    930
# B30_baseline                         baseline    none                   0    0.00   15.000   5.188e-13   1.000   413    870
# B30_sphere_cfg1_r4                   spherical   isotropic              1    4.00   15.105   5.460e-13   1.052   440    906
# B30_sphere_cfg2_r6                   spherical   isotropic              2    6.00   15.381   5.482e-13   1.057   442    902
# B30_sphere_cfg3_r8                   spherical   isotropic              3    8.00   15.872   5.446e-13   1.050   442    896
# B30_sphere_cfg4_r10                  spherical   isotropic              4   10.00   16.702   5.430e-13   1.047   434    884
# B30_sphere_cfg5_r12                  spherical   isotropic              5   12.00   17.853   5.198e-13   1.002   422    861
# B30_ellipsoid_flow_cfg1_9_5_5        ellipsoidal flow_stretched         1    6.08   15.380   5.011e-13   0.966   436    888
# B30_ellipsoid_flow_cfg2_11_6_6       ellipsoidal flow_stretched         2    7.34   15.672   5.246e-13   1.011   440    891
# B30_ellipsoid_flow_cfg3_13_7_7       ellipsoidal flow_stretched         3    8.60   16.069   5.659e-13   1.091   436    883
# B30_ellipsoid_flow_cfg4_15_8_8       ellipsoidal flow_stretched         4    9.86   16.591   5.336e-13   1.029   435    884
# B30_ellipsoid_flow_cfg5_17_9_9       ellipsoidal flow_stretched         5   11.13   17.265   5.838e-13   1.125   431    880
# B30_ellipsoid_orth_cfg1_5_5_9        ellipsoidal orthogonal_stretched   1    6.08   15.396   4.975e-13   0.959   440    892
# B30_ellipsoid_orth_cfg2_6_6_11       ellipsoidal orthogonal_stretched   2    7.34   15.690   5.064e-13   0.976   442    895
# B30_ellipsoid_orth_cfg3_7_7_13       ellipsoidal orthogonal_stretched   3    8.60   16.099   5.118e-13   0.986   440    881
# B30_ellipsoid_orth_cfg4_8_8_15       ellipsoidal orthogonal_stretched   4    9.86   16.631   5.172e-13   0.997   435    874
# B30_ellipsoid_orth_cfg5_9_9_17       ellipsoidal orthogonal_stretched   5   11.13   17.337   5.112e-13   0.985   430    872

# %% [markdown]
# ## Post-vug Image Slices For All Realizations
#
# For each baseline realization, show middle YZ slices (`x = mid_x`) for all
# post-inclusion vug configurations, grouped by orientation family.

# %%
templates_by_orientation = {
    "spherical": [t for t in vug_templates if t["orientation"] == "isotropic"],
    "flow_stretched": [
        t for t in vug_templates if t["orientation"] == "flow_stretched"
    ],
    "orthogonal_stretched": [
        t for t in vug_templates if t["orientation"] == "orthogonal_stretched"
    ],
}
orientation_order = ["spherical", "flow_stretched", "orthogonal_stretched"]
orientation_titles = {
    "spherical": "Spherical",
    "flow_stretched": "Ellipsoidal (flow-stretched)",
    "orthogonal_stretched": "Ellipsoidal (orthogonal-stretched)",
}

ncols_after = max(len(templates_by_orientation[key]) for key in orientation_order)
nrows_after = len(orientation_order)

for baseline_id in iter_progress(
    sorted(baseline_images.keys()),
    desc="Plotting post-vug slice atlases",
    total=len(baseline_images),
    enabled=USE_TQDM,
    leave=True,
):
    fig, axes = plt.subplots(
        nrows_after,
        ncols_after,
        figsize=(3.1 * ncols_after, 2.9 * nrows_after),
        squeeze=False,
    )
    for row_idx, orientation_key in enumerate(orientation_order):
        row_templates = templates_by_orientation[orientation_key]
        for col_idx in range(ncols_after):
            ax = axes[row_idx, col_idx]
            if col_idx >= len(row_templates):
                ax.axis("off")
                continue
            tpl = row_templates[col_idx]
            case_name = f"B{baseline_id}_{tpl['case']}"
            im = case_void_images[case_name]
            ax.imshow(im[mid_x], cmap="gray", origin="lower")
            ax.set_title(f"{tpl['case']}", fontsize=9)
            ax.set_xlabel("z")
            ax.set_ylabel("y")
            if col_idx == 0:
                ax.annotate(
                    orientation_titles[orientation_key],
                    xy=(-0.42, 0.5),
                    xycoords="axes fraction",
                    va="center",
                    ha="right",
                    fontsize=9,
                    rotation=90,
                )

    fig.suptitle(
        f"Baseline B{baseline_id}: post-vug middle YZ slices (x={mid_x})", fontsize=12
    )
    plt.tight_layout()
    plt.show()
# Out:
# Plotting post-vug slice atlases:   0%|          | 0/30 [00:00<?, ?it/s]
# Plotting post-vug slice atlases:   3%|▎         | 1/30 [00:00<00:12,  2.35it/s]
# Plotting post-vug slice atlases:   7%|▋         | 2/30 [00:00<00:11,  2.45it/s]
# Plotting post-vug slice atlases:  10%|█         | 3/30 [00:01<00:10,  2.49it/s]
# Plotting post-vug slice atlases:  13%|█▎        | 4/30 [00:01<00:10,  2.52it/s]
# Plotting post-vug slice atlases:  17%|█▋        | 5/30 [00:02<00:09,  2.52it/s]
# Plotting post-vug slice atlases:  20%|██        | 6/30 [00:02<00:09,  2.53it/s]
# Plotting post-vug slice atlases:  23%|██▎       | 7/30 [00:02<00:09,  2.53it/s]
# Plotting post-vug slice atlases:  27%|██▋       | 8/30 [00:03<00:08,  2.54it/s]
# Plotting post-vug slice atlases:  30%|███       | 9/30 [00:03<00:08,  2.54it/s]
# Plotting post-vug slice atlases:  33%|███▎      | 10/30 [00:03<00:07,  2.53it/s]
# Plotting post-vug slice atlases:  37%|███▋      | 11/30 [00:04<00:07,  2.45it/s]
# Plotting post-vug slice atlases:  40%|████      | 12/30 [00:04<00:07,  2.37it/s]
# Plotting post-vug slice atlases:  43%|████▎     | 13/30 [00:05<00:07,  2.40it/s]
# Plotting post-vug slice atlases:  47%|████▋     | 14/30 [00:05<00:06,  2.36it/s]
# Plotting post-vug slice atlases:  50%|█████     | 15/30 [00:06<00:06,  2.41it/s]
# Plotting post-vug slice atlases:  53%|█████▎    | 16/30 [00:08<00:12,  1.14it/s]
# Plotting post-vug slice atlases:  57%|█████▋    | 17/30 [00:08<00:09,  1.37it/s]
# Plotting post-vug slice atlases:  60%|██████    | 18/30 [00:08<00:07,  1.59it/s]
# Plotting post-vug slice atlases:  63%|██████▎   | 19/30 [00:09<00:06,  1.79it/s]
# Plotting post-vug slice atlases:  67%|██████▋   | 20/30 [00:09<00:05,  1.97it/s]
# Plotting post-vug slice atlases:  70%|███████   | 21/30 [00:10<00:04,  2.10it/s]
# Plotting post-vug slice atlases:  73%|███████▎  | 22/30 [00:10<00:03,  2.22it/s]
# Plotting post-vug slice atlases:  77%|███████▋  | 23/30 [00:10<00:03,  2.31it/s]
# Plotting post-vug slice atlases:  80%|████████  | 24/30 [00:11<00:02,  2.35it/s]
# Plotting post-vug slice atlases:  83%|████████▎ | 25/30 [00:11<00:02,  2.40it/s]
# Plotting post-vug slice atlases:  87%|████████▋ | 26/30 [00:11<00:01,  2.44it/s]
# Plotting post-vug slice atlases:  90%|█████████ | 27/30 [00:12<00:01,  2.47it/s]
# Plotting post-vug slice atlases:  93%|█████████▎| 28/30 [00:12<00:00,  2.37it/s]
# Plotting post-vug slice atlases:  97%|█████████▋| 29/30 [00:13<00:00,  2.36it/s]
# Plotting post-vug slice atlases: 100%|██████████| 30/30 [00:13<00:00,  2.19it/s]

# %% [markdown]
# ## Aggregate response across baselines
#
# For each vug template, we summarize mean ± std across the 15 baseline realizations.

# %%
aggregated: dict[tuple[str, str, int], dict[str, object]] = {}
for row in all_results:
    family = str(row["family"])
    if family == "baseline":
        continue
    key = (family, str(row["orientation"]), int(row["config_index"]))
    if key not in aggregated:
        aggregated[key] = {
            "equivalent_radius_vox": float(row["equivalent_radius_vox"]),
            "k_ratio": [],
            "phi_image": [],
        }
    aggregated[key]["k_ratio"].append(float(row["K_ratio_to_baseline"]))
    aggregated[key]["phi_image"].append(float(row["phi_image"]))

orientation_groups = [
    ("spherical", "isotropic", "tab:blue"),
    ("ellipsoidal", "flow_stretched", "tab:green"),
    ("ellipsoidal", "orthogonal_stretched", "tab:orange"),
]

fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))
for family, orientation, color in orientation_groups:
    keys = sorted(
        [k for k in aggregated if k[0] == family and k[1] == orientation],
        key=lambda k: k[2],
    )
    if not keys:
        continue
    r_eq = np.array([aggregated[k]["equivalent_radius_vox"] for k in keys], dtype=float)
    k_mean = np.array([np.mean(aggregated[k]["k_ratio"]) for k in keys], dtype=float)
    k_std = np.array([np.std(aggregated[k]["k_ratio"]) for k in keys], dtype=float)
    phi_mean = 100.0 * np.array(
        [np.mean(aggregated[k]["phi_image"]) for k in keys], dtype=float
    )
    phi_std = 100.0 * np.array(
        [np.std(aggregated[k]["phi_image"]) for k in keys], dtype=float
    )

    label = f"{family} | {orientation}"
    axes[0].errorbar(
        r_eq,
        phi_mean,
        yerr=phi_std,
        marker="o",
        linewidth=2,
        capsize=4,
        color=color,
        label=label,
    )
    axes[1].errorbar(
        r_eq,
        k_mean,
        yerr=k_std,
        marker="o",
        linewidth=2,
        capsize=4,
        color=color,
        label=label,
    )

axes[0].set_xlabel("Equivalent vug radius [voxel]")
axes[0].set_ylabel("Image porosity [%]")
axes[0].set_title("Porosity response (mean ± std over baselines)")
axes[0].grid(alpha=0.3, linestyle=":")
axes[0].legend()

axes[1].axhline(1.0, color="black", linestyle="--", linewidth=1.5, label="baseline")
axes[1].set_xlabel("Equivalent vug radius [voxel]")
axes[1].set_ylabel(f"Normalized permeability K{FLOW_AXIS}/K{FLOW_AXIS}0")
axes[1].set_title("Permeability response (mean ± std over baselines)")
axes[1].grid(alpha=0.3, linestyle=":")
axes[1].legend()

fig.suptitle("Multi-realization vug sensitivity summary")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## K/K0 Frequency Distributions By Equivalent Radius
#
# For each equivalent vug radius, this section plots histograms of `K/K0`
# distributions for the available vug configurations (across all baseline realizations).
# Radii are grouped using a two-decimal rounding to avoid floating-point key noise.

# %%
kk0_by_radius_and_config: dict[float, dict[str, list[float]]] = {}
for row in all_results:
    if str(row["family"]) == "baseline":
        continue
    radius_key = round(float(row["equivalent_radius_vox"]), 2)
    cfg_label = (
        f"{row['family']} | {row['orientation']} | cfg{int(row['config_index'])}"
    )
    if radius_key not in kk0_by_radius_and_config:
        kk0_by_radius_and_config[radius_key] = {}
    if cfg_label not in kk0_by_radius_and_config[radius_key]:
        kk0_by_radius_and_config[radius_key][cfg_label] = []
    kk0_by_radius_and_config[radius_key][cfg_label].append(
        float(row["K_ratio_to_baseline"])
    )

radius_keys = sorted(kk0_by_radius_and_config.keys())
ncols_hist = min(4, max(1, len(radius_keys)))
nrows_hist = (len(radius_keys) + ncols_hist - 1) // ncols_hist
fig, axes = plt.subplots(
    nrows_hist, ncols_hist, figsize=(4.2 * ncols_hist, 3.2 * nrows_hist), squeeze=False
)

for ax, radius_key in zip(axes.flat, radius_keys):
    cfg_map = kk0_by_radius_and_config[radius_key]
    for cfg_label, values in sorted(cfg_map.items()):
        vals = np.asarray(values, dtype=float)
        if vals.size == 0:
            continue
        if vals.size < 3 or np.allclose(vals, vals[0]):
            center = float(vals.mean())
            bins = np.array([center - 0.03, center + 0.03], dtype=float)
        else:
            bins = np.histogram_bin_edges(vals, bins=min(10, max(5, vals.size // 2)))
        ax.hist(
            vals,
            # bins=bins,
            alpha=0.55,
            edgecolor="black",
            linewidth=0.8,
            label=f"{cfg_label} (n={vals.size})",
        )
    ax.set_title(f"r_eq = {radius_key:.2f} voxel")
    ax.set_xlabel("K/K0")
    ax.set_ylabel("Frequency")
    ax.grid(alpha=0.3, linestyle=":")
    ax.legend(fontsize=7)

for ax in axes.flat[len(radius_keys) :]:
    ax.axis("off")

fig.suptitle("K/K0 frequency distributions parametrized by equivalent vug radius")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plotly pore-network visualization for all results
#
# This cell displays the pore network with pressure coloring for **every solved case**.

# %%
print("Total Plotly figures:", len(all_diagnostics))
notebooks_env = os.environ.get("VOIDS_NOTEBOOKS_PATH")
if notebooks_env:
    notebooks_base = Path(notebooks_env).expanduser()
else:
    cwd = Path.cwd().resolve()
    repo_root = None
    for candidate in (cwd, *cwd.parents):
        if (candidate / "pixi.toml").exists() and (
            candidate / "src" / "voids"
        ).exists():
            repo_root = candidate
            break
    if repo_root is not None:
        notebooks_base = repo_root / "notebooks"
    else:
        notebooks_base = cwd
plotly_export_root = notebooks_base / "outputs/08_mwe_image_based_vug_shape_sensitivity"
plotly_html_dir = plotly_export_root / "plotly_html"
plotly_png_dir = plotly_export_root / "plotly_png"
plotly_html_dir.mkdir(parents=True, exist_ok=True)
plotly_png_dir.mkdir(parents=True, exist_ok=True)
print("Plotly HTML output:", plotly_html_dir)
print("PNG output:", plotly_png_dir)

png_export_summary = {"plotly_kaleido": 0, "matplotlib_fallback": 0, "failed": 0}

for case_name in iter_progress(
    sorted(all_diagnostics.keys()),
    desc="Exporting network visualizations",
    total=len(all_diagnostics),
    enabled=USE_TQDM,
    leave=True,
):
    fig = all_diagnostics[case_name]["plotly"]
    html_path = plotly_html_dir / f"{case_name}.html"
    png_path = plotly_png_dir / f"{case_name}.png"

    # Always save interactive HTML for later inspection.
    fig.write_html(html_path, include_plotlyjs="cdn")

    # Try static Plotly PNG first (requires kaleido), then fallback to Matplotlib snapshot.
    try:
        fig.write_image(png_path, format="png", scale=2)
        png_export_summary["plotly_kaleido"] += 1
    except Exception as _:
        try:
            save_network_png_matplotlib(
                net=all_diagnostics[case_name]["net"],
                pore_pressure=np.asarray(
                    all_diagnostics[case_name]["pore_pressure"], dtype=float
                ),
                png_path=png_path,
                title=str(all_diagnostics[case_name]["plotly_title"]),
                max_throats=PLOTLY_MAX_THROATS,
            )
            png_export_summary["matplotlib_fallback"] += 1
        except Exception as exc2:
            png_export_summary["failed"] += 1
            print(f"Failed to save PNG for {case_name}: {exc2}")

print("PNG export summary:", png_export_summary)
# Out:
# Total Plotly figures: 480
# Plotly HTML output: /Users/dtvolpatto/Work/voids/notebooks/outputs/08_mwe_image_based_vug_shape_sensitivity/plotly_html
# PNG output: /Users/dtvolpatto/Work/voids/notebooks/outputs/08_mwe_image_based_vug_shape_sensitivity/plotly_png
# Exporting network visualizations: 100%|██████████| 480/480 [04:17<00:00,  1.86it/s]
# PNG export summary: {'plotly_kaleido': 0, 'matplotlib_fallback': 480, 'failed': 0}

# %% [markdown]
# ## Interpretation and caveats
#
# Observations to verify in your run:
#
# - Adding vugs increases porosity in all baseline realizations.
# - `Kabs` response is generally non-monotonic at case level and depends on connectivity
#   reorganization after extraction, not only on added void volume.
# - For similar equivalent radius, ellipsoid orientation (flow-stretched vs orthogonal)
#   can produce different transport responses.
#
# Potentially incorrect assumptions or limitations:
#
# - One centered vug does not capture stochastic spatial distributions of vugs.
# - Synthetic grayscale + Otsu may differ from real imaging artifacts and segmentation bias.
# - Results depend on the extraction model (`snow2`) and conductance model
#   (`valvatne_blunt_baseline`).
# - Even with 15 baselines, uncertainty quantification is still limited; more realizations
#   are recommended for robust inference.
